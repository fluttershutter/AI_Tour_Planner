# %%
print("ok")
# Out:
# ok

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="deellama-3.3-70b-versatile")
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 llm = ChatGroq(model="deellama-3.3-70b-versatile")
#
# File c:\Users\user\OneDrive\Desktop\Agentic AI\AI_Tour_Planner\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\user\OneDrive\Desktop\Agentic AI\AI_Tour_Planner\.venv\Lib\site-packages\langchain_groq\chat_models.py:530, in ChatGroq.validate_environment(self)
#     528 sync_specific: dict[str, Any] = {"http_client": self.http_client}
#     529 if not self.client:
# --> 530     self.client = groq.Groq(
#     531         **client_params, **sync_specific
# ...

# %%
llm.invoke("hello")
